# %% [markdown]
# ## 네이버 지식인에서 정보 가져오기

# %%
# 네이버
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "7MJsiwZO5aIph9spMJg6"
client_secret = "qaEkrVmVIH"

query = urllib.parse.quote(input("검색질의: ")) #검색어 입력 받아서 진짜로 검색하는거임
idx = 0
display = 100 #최대 100건까지 검색결과 보여줌
start = 1 #검색 시작 위치 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns = ('Title', 'Link', 'Description')) #cloumn 수 3개인 데이터 프레임 생성

for start_index in range(start, end, display):
    # json 결과, 지식인 겁색
    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
    + "&display=" + str(display)\
    + "&start=" + str(start_index)\
    + "&sort=" + sort #sort는 문자열이라 굳이 바꿀 필요 X
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    
    rescode = response.getcode()
    if(rescode==200): #정상적으로 응답받음
        response_body = response.read()
        response_dic = json.loads(response_body.decode('utf-8')) #json으로 들어온 객체를 딕셔너리로 받아오기
        print(response_dic)
        items = response_dic['items'] # item 키에 해당하는 값 가져오기
        
        for item_index in range(0,len(items)):
            # 태그를 제거하는 변수, <.*?> 는 태그안에 있는 모든 것들을 제거할 수 있게함
            r_tag = re.compile('<.*?>') #태그를 제외하기 위한 패턴 지정하기
            
            title = re.sub(r_tag, '', items[item_index]['title']) # 정규식과 매치되는 부분을 다른 문자로 변경할 수 있다
            link = items[item_index]['link']
            description = re.sub(r_tag, '', items[item_index]['description'])
            
            kin_df.loc[idx] = [title, link, description]
            idx += 1
            
    else:
        print("Error Code:" + rescode)
        
#kin_df
kin_df.to_excel('코딩.xlsx') #엑셀로 저장해보자
# Out:
# 검색질의: 코딩
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:25 +0900', 'total': 413852, 'start': 1, 'display': 100, 'items': [{'title': '<b>코딩</b>을 배우면', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=418387206&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0', 'description': '... <b>코딩</b>을 배우면서 관련 자격증 따려고 하는데, 해외 국제 대기업들에서 인정받을 수 있는 <b>코딩</b> 관련 자격증이 있을까요? 제 꿈이 개발자는 아니긴 한데, <b>코딩</b>도 배워두면 취업에 유용할 것 같아서요! 그 쪽 진로가 아니긴 한데 <b>코딩</b>... '}, {'title': '엔트리 <b>코딩</b>하는거 있잖아요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1118&docId=328179617&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0', 'description': '엔트리 <b>코딩</b>하는거 있잖아요 전자공학기술자란 직엄이랑 많이 관계있나요??  안녕하세요 메가스터디 IT 아카데미... <b>코딩</b>이라는 말의 뜻에서부터 알수 있듯이 엔트리<b>코딩</b>은 입문자가 쉽게 이해할 수 있도로 설계된 <b>코딩</b>입니다.... '}, {'title': '<b>코딩</b> 추천 교제', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=367291003&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=3&search_sort=0&spq=0', 'description': '<b>코딩</b> 공부를 하려고 하는데 초등학생 <b>코딩</b>어떤 교제가 좋을 까요? 안녕하세요 초등학생 <b>코딩</b> 교재 찾고계신데 저희가 도와드리겠습니다. <b>코딩</b>은 사람이 이해하는 언어를 컴퓨터가 이해하는 언어로 바꿔주는것을 말합니다. 꾸준히... '}, {'title': '<b>코딩</b> 스크래치로 돈벌수 있나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040202&docId=417358318&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=4&search_sort=0&spq=0', 'description': '제가 <b>코딩</b> 스크립트 이런거를 배우고있는데 아직 배우는중이라 잘하는게 스크래치밖에 없는데 뭐 없을까요?... 스크래치로는 뭐 취칙을 한다거나 이런 부분으로는 안되고요 가르치면서 돈버는?그런쪽만 될거에요 <b>코딩</b>을 직장에서... '}, {'title': '<b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10501&docId=413728785&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=5&search_sort=0&spq=0', 'description': '... 것도 <b>코딩</b> 인가요? <b>코딩</b>이 뭔지 좀 알려주세요 안녕하세요? 지식파트너 가비아입니다. <b>코딩</b>이란 C언어, 자바... 따라서 html로 웹페이지를 만드는 것 또한 <b>코딩</b>의 일종으로 볼 수 있습니다. 도움이 되었나요? 가비아였습니다. '}, {'title': '<b>코딩</b> 프로그래밍 차이', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=418309867&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=6&search_sort=0&spq=0', 'description': '<b>코딩</b>이랑 프로그래밍이랑 다른가요? 저는 같은거라고 생각했는데 주변에서 프로그래밍의 기초가 <b>코딩</b>이라는데... 하자면 <b>코딩</b>은 사람과 컴퓨터 간에 커뮤니케이션 대화 하는 형태 또는 코드를 이용하여 명령을 내리는 과정을 <b>코딩</b>이라고... '}, {'title': '<b>코딩</b> 노트북 추천', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=416921021&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=7&search_sort=0&spq=0', 'description': '... <b>코딩</b> 독학 해보려는 사람입니다. 맥북에어를 사는게 좋을까요. 삼성쪽 노트북을 사는게 좋을까요? <b>코딩</b>할... 인텔 12세대 i5 프로세서, 256GB NVMe SSD, 16GB 메모리가 탑재되어 문서작업, 웹서핑, <b>코딩</b> 등의 용도로 사용하기에... '}, {'title': '<b>코딩</b>학원 코린이도 가능한가요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=418835878&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=8&search_sort=0&spq=0', 'description': '진로를 바꿔 <b>코딩</b>에 대해 공부를 하고 이쪽 길로 나가고 싶은데 <b>코딩</b>에 대한 생각만 있고 기초지식이 없습니다 초보가 배울 수 있는 <b>코딩</b>학원 소개시켜주세요 <b>코딩</b>학원에 대해 질문해주셨는데요. <b>코딩</b>학원은 요즘처럼 젊은층에서도... '}, {'title': '<b>코딩</b> 캐드 중에 어떤 게 더 쉬운가요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1020302&docId=418518916&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=9&search_sort=0&spq=0', 'description': '... 차라리 <b>코딩</b>이 더 쉬운 수준에서도 일자리가 많지 않을까 싶기도 하고.. <b>코딩</b>과 캐드 중 어떤 게 더 쉬울까요? 1.당연히 <b>코딩</b>이 어렵습니다. 2.cad는 따라하기가 가능하지만 <b>코딩</b>은 개념이 좀 어렵다고 봅니다. 3.캐드는 고급기능을... '}, {'title': '소프트웨어고등학교에서 배우는 <b>코딩</b>이랑', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110308&docId=417993568&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=10&search_sort=0&spq=0', 'description': '... 배우는 <b>코딩</b>이랑 앤트리랑 많이 다르나요  네, 흔히들 학생 분들이 많이 접한 <b>코딩</b>의 경우에는 <b>코딩</b>을 이용하는... 소프트웨어고등학교에서 배우는 <b>코딩</b>은 실제 프로그래머들이 쓰는 개발 툴을 이용해서 작업을 하게되는 과정이죠. &amp; &amp; &amp;'}, {'title': '아두이노 <b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=414944455&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=11&search_sort=0&spq=0', 'description': '... <b>코딩</b>을 꼭 해야 하나요? 2) LED 불빛을 비추게 하려면 어떻게 해야 하죠? 1. 컴퓨터에 아두이노IDE 프로그램을... 아두이노를 <b> ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:26 +0900', 'total': 413852, 'start': 101, 'display': 100, 'items': [{'title': '<b>코딩</b> 배우려면', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=387483558&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=101&search_sort=0&spq=0', 'description': "일반인 <b>코딩</b>은 어디서 배우나요 독학해보고 싶은데 가능한가여 ★★★★ 안녕하세요 질문자님 :) <b>코딩</b>을 배우고... 알려드리는 '하우<b>코딩</b>' 이라는 새로운 교육 방법을... 문의주세요~ <b>코딩</b>일대일방문수업 <b>코딩</b>과외 자바스크립... "}, {'title': '<b>코딩</b>교육과정 어떻게 교육시키죠', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=354906164&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=102&search_sort=0&spq=0', 'description': '<b>코딩</b>교육과정 어떻게 교육시키죠 어디서 배워야 하나요.... 안녕하세요~ <b>코딩</b>교육과정 어떻게 교육시키죠 알아보시나 봅니다. 우선 이런 경우 온라인<b>코딩</b> 많이 하고... 확실하게 지도가 가능한 자바<b>코딩</b> 부터 시작해서 파이썬<b>코딩</b>... '}, {'title': '<b>코딩</b>에 대한 지식', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10501&docId=365524906&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=103&search_sort=0&spq=0', 'description': '요즘 <b>코딩</b>이 뜨는 추세라하길래 <b>코딩</b>에대해서 알고싶습니다. <b>코딩</b>이라는것에대해 전혀 아는 지식이 없구요 HTML, Java, C언어, Python 등등 뭐가 뭐지도 모릅니다. <b>코딩</b>에대해 설명좀 부탁드리고 뭐가 뭔지도 알려주시면 감사하겠습니다.... '}, {'title': '어린이과학동아 훈쌤<b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60203&docId=393828876&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=104&search_sort=0&spq=0', 'description': '어린이 과학동인에서 훈쌤<b>코딩</b>이 옛날에 나왔었 잖아요... 핼로윈 게임 만들기랑 우주게임 만들기 몇호 인가요?... 어린이 과학동인에서 훈쌤<b>코딩</b>이 옛날에 나왔었 잖아요... 핼로윈 게임 만들기랑 우주게임 만들기 몇호 인가요? &gt;해당... '}, {'title': '<b>코딩</b> 초보인데요 ..', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50105&docId=320441522&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=105&search_sort=0&spq=0', 'description': '<b>코딩</b> 초보인데요... c언어에서 자바 파이썬 언어로 변환해주는 그런거있냐요?... ★★ 안녕하세요 ★★ 자바스크립트<b>코딩</b> 가장 기초적이라고 하면서도... 다른영역일지라도 <b>코딩</b>에 대한 이해도가 달라집니다. <b>코딩</b>과외 <b>코딩</b>학원... '}, {'title': '대전입니다 <b>코딩</b>과외나 <b>코딩</b>학원 알아보고 있어요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=417524009&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=106&search_sort=0&spq=0', 'description': '... <b>코딩</b> 마땅히 없는 것 같네요. 이쪽이어도 되고 요즘엔 <b>코딩</b>온라인 많이 한다고 해서 그것도 괜찮으니 대전<b>코딩</b>배우... <b>코딩</b>자격증 까지는 아니더라도 재미있게 할 수있는 대전<b>코딩</b> 알아보고 싶어요. 대전<b>코딩</b>과외 아시는 분들은 답변... '}, {'title': '<b>코딩</b>하다가 잘 안되면', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=418191706&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=107&search_sort=0&spq=0', 'description': '직장에서 <b>코딩</b>하다가 잘 안풀리면 어떻게 하나요? 저는 잘 안되면 밖에라도 잠깐 나갔다 와야 하는 스타일이라서... <b>코딩</b>하다 안풀리면 잠시 밖에 나가서 바람 쐬고 들어왔습니다. 흡연하시는 분들은 자연스럽게 잠시 나갔다오시는데... '}, {'title': '수원<b>코딩</b>과외 또는 수원<b>코딩</b>학원 알려주세요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=417667933&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=108&search_sort=0&spq=0', 'description': '아이가 <b>코딩</b>에 관심이 많아 빨리 시켜주고싶네요. 아직... <b>코딩</b>하는 학생이 많다고 하더라고요. jv 소프트웨어 전공까지 바라보는건 아니더라도 취미 및 자기계발로 <b>코딩</b>... 안녕하세요~ 아이들 논리적 사고를 키워주는 <b>코딩</b>수업... '}, {'title': '컴공과 <b>코딩</b>??', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=269491219&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=109&search_sort=0&spq=0', 'description': '... 컴공하면 떠오르는게 <b>코딩</b>정도인데 2월달에 <b>코딩</b>을 배워놓는게 좋을까요?? 2.안배워도 되더라도 흥미가 생기는데 <b>코딩</b>을배우기전 뭘 준비해야할까요?? 3.<b>코딩</b>말고도 컴공과가 배워두면 좋은 컴퓨터관련 활동좀 알려주세요!!... '}, {'title': 'c++ 가산기 <b>코딩</b> 알려주실분', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040101&docId=418563816&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=110&search_sort=0&spq=0', 'description': 'c++ 가산기 <b>코딩</b> 알려주실분 과거에는 프로그래밍은 전문가나 개발자들 만이 하는 일이라고 생각했습니다. 대부분의... <b>코딩</b>일대일방문수업 <b>코딩</b>과외 자바스크립 프로그래밍과외 기초<b>코딩</b> <b>코딩</b>배우기 길스크래치 성인<b>코딩</b>교육... '}, {'title': '<b>코딩</b>에 대해서 설명 좀 부탁드려요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10405&docId=320065088&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=111&search_sort=0&spq=0', 'description': '안녕하세요 <b>코딩</b>을 배울려고 하는데 ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:26 +0900', 'total': 413852, 'start': 201, 'display': 100, 'items': [{'title': '<b>코딩</b> 학원 추천', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=417369550&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=201&search_sort=0&spq=0', 'description': '컴퓨터학과 2학년입니다 2학년임에도 불구하고 여전히 <b>코딩</b>이 너무 어렵고 부족합니다 방학 때 <b>코딩</b> 학원에 다니면서... 여전히 <b>코딩</b>이 어렵게 느껴지셔서 <b>코딩</b> 수업 찾고계신것같습니다. 저희가 도와드리겠습니다. 방학때 배울 수 있는... '}, {'title': 'c언어로 계산기를 <b>코딩</b>하고싶은데요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040101&docId=379334112&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=202&search_sort=0&spq=0', 'description': '<b>코딩</b> 초보입니다. c언어로 간단하게 계산기를 <b>코딩</b>하고싶은데요 <b>코딩</b>하는거 자체에는 문제가없는데 어떻게해야... 도통모르겠어요 제가하는방법은 항상 비효율적인거같아서요 하드<b>코딩</b> 이란 단어도 들어봤는데 어떤건지 잘 모릅니다... '}, {'title': '<b>코딩</b>, 게임개발 학원', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10403&docId=415585678&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=203&search_sort=0&spq=0', 'description': '... 용인에 <b>코딩</b>학원 없을까요? 된다면 수지에 있고 게임개발 학원이면... 남겨드려요 <b>코딩</b>과정과 함께 문의 남겨시면 자세하게 안내가 될 거에요... 시스템 &gt; 깔끔한 시설, 최신컴퓨터, 자습실 ▶<b>코딩</b> 교육과정 상담받기 https://vo.la/bZbgil'}, {'title': '<b>코딩</b> 배우고 싶은데 어디서 배울 수 있나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=359953666&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=204&search_sort=0&spq=0', 'description': "... 없어서 <b>코딩</b> 배워보고 싶은데 온라인으로 배울 만한데 있나요? 아님 <b>코딩</b> 관련 책 추천해주셔도 되요. 최대한 빨리 답변 부탁드려요. ★★★★ 안녕하세요 질문자님 :) <b>코딩</b>... 알려드리는 '하우<b>코딩</b>' 이라는 새로운 교육 방법을... "}, {'title': '중1)<b>코딩</b>으로 앱만들어 돈버는법', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=414675030&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=205&search_sort=0&spq=0', 'description': '... 인대 <b>코딩</b>,컴퓨터 프로그래밍이 빠지면 안되겠죠 ㅎㅎ 그래서 제가 <b>코딩</b>을 배우고 또 독학도 하고 그래서 앱이나... 60  <b>코딩</b>으로 앱을 만들어서 수익을 창출하시려면, 어느정도 <b>코딩</b> 실무능력이 받쳐줘야 합니다. 국내 앱 기반은... '}, {'title': '<b>코딩</b> 독학 어떻게하면 빨리 배우는지', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=414671825&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=206&search_sort=0&spq=0', 'description': '<b>코딩</b> 독학 어떻게하면 빨리 배우는지 알려주세요 성실히 답변해주세요  <b>코딩</b>을 공부하시려는 목적이 어떻게 되시나요? <b>코딩</b>은 충분히 독학으로 학습하실 수 있습니다. 하지만... 목적에 따른 <b>코딩</b>공부방법에 대해서 로드맵을... '}, {'title': '전주<b>코딩</b>과외 수업하시는 선생님계실까요??', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110212&docId=418343323&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=207&search_sort=0&spq=0', 'description': '... 좋아하고 <b>코딩</b>에 관심이 생겨서 가르쳐볼가 하는데 혹시 전주<b>코딩</b>과외 하시는 쌤도 계실까요~~?? 추천부타드립니다 감사합니다~~^^  안녕하세요. 하나쌤입니다^^ 전주 <b>코딩</b>과... 있는 <b>코딩</b>과외 진행 중입니다. 전주<b>코딩</b>과외 고민... '}, {'title': '<b>코딩</b>공부 처음 시작해요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=386186903&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=208&search_sort=0&spq=0', 'description': '오늘 처음으로 <b>코딩</b> 공부 하려고 하는데요. html을 vscode로 하려는데 테그를... ^^ ★★ 안녕하세요 ★★ 자바스크립트<b>코딩</b> 가장 기초적이라고 하면서도... 다른영역일지라도 <b>코딩</b>에 대한 이해도가 달라집니다. <b>코딩</b>과외 <b>코딩</b>학원... '}, {'title': '<b>코딩</b> 관련 직업', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10405&docId=414319908&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=209&search_sort=0&spq=0', 'description': '... <b>코딩</b> 관련직업이 어떤게 있을까요? 제가 장래희망을 뭘로 하면 좋을지 고민하고 있었는데요. 중학교 때부터 배운 <b>코딩</b>을 해보니까 재미가 있더라고요. 그래서 제 진로를 <b>코딩</b>과 관련된 쪽으로요. 근데 <b>코딩</b>과... '}, {'title': '<b>코딩</b>이란? 뭔가요??', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=345797702&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=210&search_sort=0&spq=0', 'description': '<b>코딩</b>에 대해 공부중인데 <b>코딩</b>으로 프로그램을 만든다고 하잖아요 도대체... ★★★★★★ 안녕하세요^^ 요즘 <b>코딩</b>이 이슈가 되면서 초등학교 와... <b>코딩</b>이란 사람의 언어를 컴퓨터의 언어로 바꿔주는건데요. sw교육이라고 칭하는... '}, {'title': '<b>코딩</b>과 포토샵', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=289748596&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=211&search_sort=0&spq=0', 'description': '<b>코딩</b>과 포토샵 공부하려하는데 따로 알아야할 프로그래밍언 ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:27 +0900', 'total': 413852, 'start': 301, 'display': 100, 'items': [{'title': '어플리케이션을 만들려면 어떤 <b>코딩</b>어를', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10401&docId=329550613&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=301&search_sort=0&spq=0', 'description': '... 어떤 <b>코딩</b>어를 시작하는게 좋을가요(게임을 만들고싶습니다) 1.배워야할<b>코딩</b> 2.관련프로그렘 3.관련교재 <b>코딩</b>이란... <b>코딩</b>을 하는 과정에서 수많은 오류와 해결하는 과정에서 문제해결 능력과 논리적 사고력을 기를 수 있습니다.... '}, {'title': '<b>코딩</b> 어떻게하죠?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=418570051&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=302&search_sort=0&spq=0', 'description': '<b>코딩</b>하려는데...  <b>코딩</b> 전에 언어부터 선택해야겠네요 언어는 종류가 너무 많습니다 어디에 사용하냐에 따라... C++을 쓰고 유니티에 C#을 쓰는 것처럼요! <b>코딩</b>부터 프로그래밍에 자세히 배우고 싶으시면 학원 다니시는거 추천드려요'}, {'title': '<b>코딩</b> 시작하는법', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040101&docId=415322134&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=303&search_sort=0&spq=0', 'description': '<b>코딩</b>은 어느 프로그램에서 하는건가요 전부 <b>코딩</b>언어 종류만 설명하고 어디에서 그것을 작성하는지... <b>코딩</b>에 대해 아무것도 모르는데 이것저것 툴을 나열하는 것보다... 요즘 트렌드는 아무래도 Visual Studio Code 로 많이 하는것... '}, {'title': '<b>코딩</b>배우고싶어요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=3120101&docId=418637982&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=304&search_sort=0&spq=0', 'description': '<b>코딩</b>하권추천해주세요 안녕하세요~ <b>코딩</b>에 관심이 있으시군여!! 요즘 <b>코딩</b>언어 배우는데 다들 열심히 하시고 있는것 같아요 아무래도 혼자 공부하는 것보다 전문학원에서 다니는 것이 좋겠죠 제가 알고있는 곳이 한군데... '}, {'title': '<b>코딩</b>언어를 알려주세요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040101&docId=416717418&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=305&search_sort=0&spq=0', 'description': '<b>코딩</b>을 배울때 가장 기초적인것을 알려주세요  프로그래밍 언어인 파이썬과 c가 <b>코딩</b>에 있어 밑바탕이 되는 과정입니다. &amp; &amp; &amp;'}, {'title': '요즘은 초등학생들이 <b>코딩</b>을 배운다는데', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=323894120&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=306&search_sort=0&spq=0', 'description': '요즘은 초등학생들이 <b>코딩</b>을 배운다는데 사실인가요? 어디선가 요즘은 초등학생들이 <b>코딩</b>을 배운다는 얘기를... 네 <b>코딩</b> 수업이 정규 과정으로 편입되어서 초등학생들이... ly/39kAdQo 그래서 저는 위 링크 클릭하면 들을 수 있는 <b>코딩</b>... '}, {'title': '<b>코딩</b> 배우기', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=401413836&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=307&search_sort=0&spq=0', 'description': '... 모르고 <b>코딩</b>도 중딩 때 아두이노 몇 번 선생님 설명에 따라 해 본 적이 다 입니다. (아직 <b>코딩</b> 단어도 거의 모른다고... 도저히 <b>코딩</b>은 어떻게 공부해야 할지 감이 안 잡히네요 안녕하세요 고등학교 1학년 학생이신데 <b>코딩</b>에 관심이... '}, {'title': '전남 광주 <b>코딩</b>학원', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=343492912&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=308&search_sort=0&spq=0', 'description': '내일배움카드로 <b>코딩</b>을 배워보랴고하는데 제가 근로자라... 추천좀해주세여  안녕하세요 <b>코딩</b>학원 문의하셔서... 유아, 초등학생, 중학생 등 어릴때부터 <b>코딩</b>교육을 받는 학생들이 점점 늘어나고 있는데요, 그마만큼 <b>코딩</b>이... '}, {'title': '<b>코딩</b> 배우면 어느 직업이 있고 학과가 있나요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=379988097&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=309&search_sort=0&spq=0', 'description': '예비 중 3입니다 <b>코딩</b>에 대해서 몇가지 물어볼 게 있어요 광고 신고합니다 1. <b>코딩</b>을 배우면 어느 학과 어느 직업이 있나요 2. <b>코딩</b>은 어떤 과목 비중이 더 높나요? (고등학교 때 챙겨야할 과목) 3. <b>코딩</b>은 지금 배워도 안 늦나요 4.많이..... '}, {'title': '<b>코딩</b> 독학', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10405&docId=414942504&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=310&search_sort=0&spq=0', 'description': '공대 희망하는 고등학교 1학년입니다 시간 나는 짬짬히 <b>코딩</b> 미리 공부하고 싶은데 뭐부터 어떻게 시작하는 게 좋을 지 알려주세요... ㅠㅠ  <b>코딩</b>을 미리 공부하고싶다면 프로그래밍 언어들 중 기본적으로 널리 쓰이는 파이썬과 c를 우선... '}, {'title': '부산에 <b>코딩</b>학원추천해주세요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=414986238&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=311&search_sort=0&spq=0', 'description': '... 괜찮은 <b>코딩</b>학원이 있을까요 추천 부탁드려요  이 사실을 아실지는 모르겠지만 18년도부터 전국에서는 <b>코딩</b>교육... 부산<b>코딩</b>자격증 부산진구<b>코딩</b>단기완성 서면알고리즘 남포동왕초보<b>코딩</b> 사실 너무 어려워서 시도조차 ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:27 +0900', 'total': 413852, 'start': 401, 'display': 100, 'items': [{'title': '<b>코딩</b>완전 초보', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10405&docId=414613501&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=401&search_sort=0&spq=0', 'description': '... (블럭<b>코딩</b>)도 못합니다. 컴퓨터 기초 언어도 모르구요..이진법? 십진법도 잘 모릅니다. 근데 주변에 <b>코딩</b>잘... 유익하게 <b>코딩</b>을 배울수있는 강좌나 책이 있을까요? 정확한 답변 부탁드려요ㅠ 1. <b>코딩</b> 강좌(사이트) 2.... '}, {'title': '스크래치 <b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040201&docId=389968099&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=402&search_sort=0&spq=0', 'description': '... <b>코딩</b> 신박한 아이디어 좀 추천해주세요.. 안녕하세요 스크래치<b>코딩</b> 신박한 아이디어 찾고계신데 스크래치<b>코딩</b>에... 저희는 유아부터 초등학생 중학생 고등학생 성인까지 <b>코딩</b>수업을 하고있습니다. 대학생이나 알바선생님이 아닌... '}, {'title': '<b>코딩</b> 취업', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=416266971&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=403&search_sort=0&spq=0', 'description': '... 때 <b>코딩</b>은 실력을 많이 본다던데 4년제 대학 컴공 아무대나 졸업하면... 지금은 <b>코딩</b>을 때려치우고 공부를 쭉 해야할까요ㅠ..?? 중2까지 html, css... 성적이 좋다면 디미고 선린고 쪽으로 알아보고, 아니면 일반고에서도 충분히 <b>코딩</b>으로... '}, {'title': '<b>코딩</b> 어떻게하죠?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=418570051&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=404&search_sort=0&spq=0', 'description': '<b>코딩</b>하려는데...  안녕하세요 메가스터디 IT 아카데미 학사관리자입니다~! ^^ 2008년 토익붐때처럼 현재 IT붐은... 다시말해 대부분의 유명하고 잘가르쳐주는 <b>코딩</b>학원들은 강남역 인근에 있지요 메가스터디 IT 아카데미에서는... '}, {'title': '<b>코딩</b>수업 듣고 싶습니다 도와주세요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=418716210&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=405&search_sort=0&spq=0', 'description': '... <b>코딩</b>수업을 듣고 흥미가 생겼는데 학교에서 배우는 것만으로는 이해도 살짝 부족하고 더 배우고 싶어서 <b>코딩</b>수업... 안녕하세요 IT컨설턴트로 근무하고 있는 선생님 입니다~ 우선 <b>코딩</b>수업 관련해서 문의를 남겨주셨습니다~ <b>코딩</b>수... '}, {'title': '<b>코딩</b>교육이 요즘 뜨는것 같은데 주말에', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=315099521&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=406&search_sort=0&spq=0', 'description': '<b>코딩</b>교육이 요즘 뜨는것 같은데 주말에 전문적으로 가르치는 학원이나... 안녕하세요 <b>코딩</b>학원 <b>코딩</b>교습소 관련해서 질문 올려주셨네요~ 중학생인데... 온라인<b>코딩</b>수업 쪽이 더 잘 맞습니다! 4차 산업혁명 시대가 도래함에 따라 STEM... '}, {'title': '중학생 고등학생 <b>코딩</b>공부', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1104&docId=276303875&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=407&search_sort=0&spq=0', 'description': '... 그러다가 학교에서 <b>코딩</b>공부를 한다는데 재밌다고 해서... 고등학생 <b>코딩</b>공부 왠만하면 직접 학원같은데... 중학생 고등학생 <b>코딩</b>공부 잘아시는분 답변좀 해주세요... 프로그래밍 <b>코딩</b> 강의를 실전예제 위주로, 저렴하게 수강할 수... '}, {'title': '<b>코딩</b>을좋아하는이제5학년입니다ㅠ', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10405&docId=321923092&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=408&search_sort=0&spq=0', 'description': '<b>코딩</b>을좋아하는이제5학년입니다ㅠ (내공50검) 제가전학을왔어요 전학교홈페이지에들어가보니제가 없을때... 제가좋아하는<b>코딩</b>방과후가 생겼어요ㅠ 이제중1부터<b>코딩</b>을한다는데 저는 <b>코딩</b>학원이나 <b>코딩</b> 방과후를 다니고싶어요! 조치원에... '}, {'title': '<b>코딩</b> 자격증1 종', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=413550304&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=409&search_sort=0&spq=0', 'description': '저는 현재 중1 학생 입니다 제가 올해 부터 <b>코딩</b>에 관심이... 질문자님, <b>코딩</b>자격증보다는 리눅스마스터 네트워크관리사를... 그래도 <b>코딩</b>자격증을 취득하고 싶다고 하신다면 2종만 취득하셔도 도움이 될 것이랍니다 :) <b>코딩</b>은 독학보다는... '}, {'title': '<b>코딩</b> 질문', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=415263958&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=410&search_sort=0&spq=0', 'description': '최근에 <b>코딩</b>에관심이생겼는데 궁금한게있어... <b>코딩</b>할려면 수학도 잘해야한다고하던데 어느정도까지... 4.<b>코딩</b> 쪽 전망은어떤가요? 5.지금 23살인데 지금시작해도... <b>코딩</b>을 하는데 있어 수학을 잘하는 것은 실질적으로 컴공과를 진학... '}, {'title': '초등학생 대상 <b>코딩</b>교육', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=336083797&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=411&search_sort=0&spq=0', 'description': '현재 실내디자인과 재학중인 학생인데요, 초등학생을 대상으로 <b>코딩</b>을... 초등학생을 대상으로 <b>코딩</b>을 가르치는 교육방법은? 2. <b ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:28 +0900', 'total': 413852, 'start': 501, 'display': 100, 'items': [{'title': '<b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=413809631&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=501&search_sort=0&spq=0', 'description': '사람들이 취업용으로 <b>코딩</b> 배우는 추세가 있던데 <b>코딩</b>이 정확히 무엇이며, <b>코딩</b> 배우는데 필요한 비용 및 조건은 무엇이며, 대학진학이 필요한 기술인지?, <b>코딩</b> 자격증(?)만 있으면 취업가능하며 연봉은 높은 편이며 난이도는 높은... '}, {'title': '태평역 부근에 <b>코딩</b>교육 학원이 있나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110313&docId=279567107&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=502&search_sort=0&spq=0', 'description': '태평역 부근에 <b>코딩</b>교육 학원이 있나요? 저는 초등학생과... 교육으로 <b>코딩</b>수업이 이루어진다고 해서 방학기간 동안 가르쳐볼까 해서 질문합니다 <b>코딩</b>수업은 바로 본수업으로... 저희 <b>코딩</b> 수업은 아가들이 한글을 배우고 숫자를 배우는... '}, {'title': '<b>코딩</b>학원요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=412464953&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=503&search_sort=0&spq=0', 'description': '... 하길래 <b>코딩</b>을 가르켜볼까 하는데 제가 잘 몰라서요 <b>코딩</b> 가장 기초단계는... 안녕하세요~ <b>코딩</b>교육 상담을 도와드리고 있습니다 처음 시작을 하시는... 우선 <b>코딩</b>교육을 받으시더라도 공부하시는 목표설정부터 수업을 들을때의... '}, {'title': '유니티 <b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10403&docId=407886689&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=504&search_sort=0&spq=0', 'description': '유니티 게임<b>코딩</b> 하려면 맨 처음 배워야하는 언어가 뭐예요?? 유니티를 배우기 위해서는 C#을 공부하셔야 하고 <b>코딩</b>을 처음 해보시는 거면 C언어를 공부하셔야 합니다!! '}, {'title': '천재교육 밀크T아이 <b>코딩</b> 난이도 어때요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110101&docId=417525931&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=505&search_sort=0&spq=0', 'description': '... <b>코딩</b>에 대해서는 집에서 가르쳐줄 수 없더라고요. 어린이집에서 해주는 것도 아니고요. <b>코딩</b>만 학원을 보내려니 신경 써야 할 부분이 많은데 해줄 수가 없어요. <b>코딩</b> 학습을 위해 방법을 찾다 보니 천재교육 밀크T아이에서 <b>코딩</b>도 배울... '}, {'title': '그 누구도 <b>코딩</b>의', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110414&docId=418061727&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=506&search_sort=0&spq=0', 'description': '천재가 될수있습니다. 10년간 <b>코딩</b>을 매일 하루에 10시간씩 한다면요. 이말이 사실인가요?  그 누구도 <b>코딩</b>의 천재가 될수있습니다. 10년간 <b>코딩</b>을 매일 하루에 10시간씩 한다면요. 이말이 사실인가요? 네 맞습니다. 가능합니다.'}, {'title': '<b>코딩</b>vs회계세무', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1128&docId=417107299&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=507&search_sort=0&spq=0', 'description': '... 요즘 <b>코딩</b> 개발자에 관심도가 매우 높아서 한번 배워보고는 싶은데 회사 일을 하면서 <b>코딩</b>을 배운다면 시간이... 발 담궈보고 그 이후에 재밌으면 이직해도되는거구요 <b>코딩</b>학원 알려드릴테니 이쪽 통해서 궁금한 부분들 물어보세요'}, {'title': '<b>코딩</b> 캐드', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1020302&docId=412380547&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=508&search_sort=0&spq=0', 'description': '<b>코딩</b>이랑 캐드가 아예 다른 면일까요? 보통 학원들 보면 <b>코딩</b> 학원 따로 캐드 학원 따로일까여? 두 과목을 한... 그래서 <b>코딩</b>을 배울거면 <b>코딩</b> 혹은 컴퓨터 프로그래밍 &amp; 전공 공부를 가르치는 컴퓨터 학원을 찾고, 캐드를 배울거면... '}, {'title': '<b>코딩</b> 포기할까요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406001841&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=509&search_sort=0&spq=0', 'description': '... 그냥 <b>코딩</b> 때려치는 게 낫겠죠? 지금 대학 교양과목으로... 개발자 되면 맨날 <b>코딩</b> 생각하고 머리 쥐어짜야 된다던데 귀찮을 것 같고 어릴 때부터 수학을 싫어했어서 <b>코딩</b>은... 어문 전공인데 취업이 될지 모르겠어서 <b>코딩</b> 건드려보는데... '}, {'title': '<b>코딩</b> 자격증', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=13&dirId=130208&docId=411803803&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=510&search_sort=0&spq=0', 'description': '안녕하세요 예비중1입니다 제가 <b>코딩</b> 자격증을 딸려고 하는데 많이 어렵나요…? 학교 <b>코딩</b> 수업시간에서도 거의 빠졌어서… <b>코딩</b>관련된 자격증을 따려면 3,4개월 정도 공부를 하셔야합니다. <b>코딩</b>관련된 직업을 하고 싶으시다면 미리... '}, {'title': '성남 <b>코딩</b> 학원 질문', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=402456096&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=511&search_sort=0&spq=0', 'description': '성남에 <b>코딩</b> 학원 있나용 있으면 위치도 알려주세요 <b>코딩</b>은 독학으로 성공하는 것은 극히 드뭅니다. 성남초등<b>코딩</b>수업 성남중둥<b>코딩</b>수업 성남고등코등수업 성남성인<b>코딩</b>수업 분당일대일<b>코딩</b>수업 분당<b>코딩</b> ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:28 +0900', 'total': 413852, 'start': 601, 'display': 100, 'items': [{'title': '<b>코딩</b> 프로그래밍 잘하면 질문이요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=415161035&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=601&search_sort=0&spq=0', 'description': '<b>코딩</b> 프로그래밍을 잘하면 앱어플이나 웹사이트를 돈 안들이고 혼자서 만들 수 있나요?  네 만들수있어요 <b>코딩</b>배우는거에 관심있으시면 여기 전문학원인데 채팅상담이라도 해보세요 자세히 알려줘요'}, {'title': '양산 <b>코딩</b>학원', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=415343510&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=602&search_sort=0&spq=0', 'description': '23살 대학생입니다 경남 양산에 파이썬, 파이참같은 <b>코딩</b>학원 있을까요?... (웹<b>코딩</b>),반응형 웹 프로젝트 안드로이드앱 개발,아이폰앱 개발... 정보보안기사/산업기사 <b>코딩</b>강사양성 &lt;네트워크 관리자&gt; 네트워크 엔지니어... '}, {'title': '동탄초등<b>코딩</b>과외 구하는데 잘하는 곳 있나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=418843991&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=603&search_sort=0&spq=0', 'description': '초등학생 조카가 <b>코딩</b>을 배우고 싶어합니다. 동탄초등<b>코딩</b>과외 경력있으신 분이면 좋겠는데, 잘하시는분 있으면... 처음 시작하는 학생이라, <b>코딩</b> 기초부터 꼼꼼하게 봐주시면 좋을거 같습니다. ^^  안녕하세요 질문자님 <b>코딩</b>은... '}, {'title': '<b>코딩</b> 공부 생초보도 가능한가요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110703&docId=406416915&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=604&search_sort=0&spq=0', 'description': '... <b>코딩</b> 공부 하고 나서 이직을 생각하는데... 저 같은 생초보도 <b>코딩</b> 공부해서 취업이 가능할까요? 안녕하세요. 돌곶이물주먹입니다. <b>코딩</b> 공부, 사실 어떤 공부든 생초보도... 다만, 현재 이직까지 고려하시면서 <b>코딩</b> 공부를 하시려고... '}, {'title': '자바스크립트 <b>코딩</b> 중학생 하기 어렵나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040202&docId=417627590&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=605&search_sort=0&spq=0', 'description': '... 자바스크립트 <b>코딩</b> 중학생 처음 배우기 어렵나요? 꿈이... 안녕하세요~ 자바스크립트 <b>코딩</b> 중학생 하기 어렵나요? 알아보시나 봅니다. 우선 이런 경우 온라인<b>코딩</b> 많이... 확실하게 지도가 가능한 자바<b>코딩</b> 부터 시작해서... '}, {'title': '<b>코딩</b>배우기 학원이 좋나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=414884927&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=606&search_sort=0&spq=0', 'description': '이번에 중학생이 됐는데 그전부터 관심있던 <b>코딩</b>을 배우고 싶어서요 <b>코딩</b>배우기가 독학으론 힘들고 학원이 괜찮을것 같은데 <b>코딩</b>학원 잘하는곳 추천을 받고싶어요  안녕하세요~ 중고등학생 <b>코딩</b>교육 상담을 도와드리고 있는데요 이제... '}, {'title': '<b>코딩</b> 얼마나 배워야지 잘하나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=416167992&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=607&search_sort=0&spq=0', 'description': '<b>코딩</b> 얼마나 배워야지 잘하나요?  C언어나 파이썬 자바같은 기본적인 프로그래밍 언어를 배우신다 하시면 한 언어에 2... 하고 <b>코딩</b>을 배워서 취업을 생각하시거나 <b>코딩</b>으로 웹을 만든다거나 하는 심화적인 과정을 생각하실경우 적어도... '}, {'title': '문과생 <b>코딩</b>에대한 각종 질문', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=414164919&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=608&search_sort=0&spq=0', 'description': '... 취업문제로 인해 <b>코딩</b>에 관심이 생겼는데. 1.개발쪽은 통계수학을... <b>코딩</b> 직종에대한 간략해서 설명 부탁드립니다. 3. <b>코딩</b> 직종에대한 국가고시... 문과생이 <b>코딩</b>쪽 직종을 간다면 최대한 거부감이 없는 직종은 어디인지 5. 제가... '}, {'title': '<b>코딩</b> 및 데이터 과학', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=413587666&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=609&search_sort=0&spq=0', 'description': '... 아마 <b>코딩</b>을 쓸 일이 빈번할것 같아 지금부터 좀 손에 익혀두고 싶어요. 그래서 <b>코딩</b>을 어떻게 시작해야 하며... 등등 <b>코딩</b>에 대해 잘 알아가는 방법과 팁 정도를... 요즘 <b>코딩</b>이 단연 화제인데요. 프로그램의 본산인 미국에서는... '}, {'title': '<b>코딩</b>에 관해서', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=412240608&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=610&search_sort=0&spq=0', 'description': '<b>코딩</b>에 관해서 궁금한것이 있는데요 <b>코딩</b>으로 어디까지 <b>코딩</b>이 쓰이는지 궁금한데요 앱과 웹사이트말고 발전소나... 사용하는게 <b>코딩</b>인가요? <b>코딩</b>이 기본으로 시작하는건가요?(컴퓨터가 있는곳) 제가 관심이있는 분야가 있습니다... '}, {'title': '기계설계과 <b>코딩</b> 취업', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1126&docId=417599262&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=611&search_sort=0&spq=0', 'description': '... 기계설계만 하기엔 너무 좁은것같아 <b>코딩</b>공부를 같이해서 취업해볼까 하는데 기계설계와 <b>코딩</b> 지식을... 기초 <b>코딩</b>부터 빅데이 ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:29 +0900', 'total': 413852, 'start': 701, 'display': 100, 'items': [{'title': '대구<b>코딩</b>학원 추천좀 해주세요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1107&docId=280853959&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=701&search_sort=0&spq=0', 'description': '<b>코딩</b>교육 잘하는 곳으로좀 부탁드립니다. 지금 힘들다고 포기하는것은 정말 안타까운 행동중에 하나라고 보시면... <b>코딩</b>일대일방문수업 <b>코딩</b>과외 자바스크립 프로그래밍과외 기초<b>코딩</b> <b>코딩</b>배우기 길스크래치 성인<b>코딩</b>교육... '}, {'title': '고등학생 방과후 <b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=413205821&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=702&search_sort=0&spq=0', 'description': '컴공과를 희망하고 있는 고3학생인데 방과후 선택지로 <b>코딩</b>이 나왔더라구요 지금 고민중인건 과탐 과목을 수강해서 과탐을 튼튼하게 할지 아님 <b>코딩</b>을 배울지 고민입니다. 고등학생때 <b>코딩</b> 배우는거 괜찮을까요?  <b>코딩</b>을 배우면... '}, {'title': '자바<b>코딩</b> 질문', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040201&docId=399627986&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=703&search_sort=0&spq=0', 'description': '자바<b>코딩</b> 쉽게하는 방법 없을까요  안녕하세요. <b>코딩</b>을 전문으로 일대일과외를 진행하고 있습니다. <b>코딩</b>은 미래의... <b>코딩</b>이란? 컴퓨터가 다양한 동작을 수행하도록 사람이 지시사항을 입력해 프로그래밍 언어로 작성하는 행위 (노트북... '}, {'title': '<b>코딩</b>관련 질문이요.', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=410131766&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=704&search_sort=0&spq=0', 'description': '... 하면서 <b>코딩</b>을 하는 게 좋을까요? 2. <b>코딩</b>...독학으로는 안되겠죠? 3. 독학이... <b>코딩</b> 자격증이나 시험일자, 공부를 할 때 알아두면 좋은 것들 다... 네 웹개발은 물론이고 웹디자인 요즘은 <b>코딩</b>이 필수 입니다 2. 독학으로는 많이... '}, {'title': '나주<b>코딩</b>언어학원 있나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040101&docId=389960584&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=705&search_sort=0&spq=0', 'description': '나주<b>코딩</b>언어학원 있나요? 씨언어만 배우고싶은데 단기로 배우는 학원이있는지 궁금합니다. 내가 지금부터 <b>코딩</b>에... <b>코딩</b>일대일방문수업 <b>코딩</b>과외 자바스크립 프로그래밍과외 기초<b>코딩</b> <b>코딩</b>배우기 길스크래치 성인<b>코딩</b>교육... '}, {'title': '목포<b>코딩</b>학원 다니시는 분 계시나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=412921681&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=706&search_sort=0&spq=0', 'description': '목포에도 <b>코딩</b>학원 많이 있나요? 요즘 <b>코딩</b>이 필수라고 해서... 저도 뒤쳐지고 싶지 않아 <b>코딩</b>을 배워보려고 합니다  목포<b>코딩</b>학원을 찾으시는군요 ㅋㅋㅋ 동지!!!! 저도 요즘 <b>코딩</b>공부해서 개발자되고 싶어가지구 여기저기 다녀봤어요... '}, {'title': '파주 운정 초등 학생 <b>코딩</b> 시키고 싶어요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110212&docId=417509887&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=707&search_sort=0&spq=0', 'description': '... 파주운정초등학생<b>코딩</b> 시키고 싶어서 알아보고 있어요 여기저기 알아보니까 요즘에는 어린이<b>코딩</b> 필수과목이라고 하더라구요 그래서 파주운정초등<b>코딩</b> 알앙보고... 요즘은 초등학생부터 <b>코딩</b>배우죠ㅠㅠㅠㅠㅠ 너무 어려운데... '}, {'title': '대구 <b>코딩</b> 교육 받을 수 있는 곳 추천', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=391486639&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=708&search_sort=0&spq=0', 'description': '대구 <b>코딩</b> 교육 받을 수 있는 곳 추천해주세요 올해 중1 남자아이 <b>코딩</b>을 배우게 하려합니다. 기초부터 컴퓨터 <b>코딩</b>을 배웠으면 합니다 <b>코딩</b>은 기본적으로 컴퓨터 언어라고 보시면 되는것입니다 그것을 프로그래밍화 해서 어떻게... '}, {'title': '<b>코딩</b> 활용, <b>코딩</b>과 행정', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=405905296&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=709&search_sort=0&spq=0', 'description': '... <b>코딩</b>이 실제로 어떻게 활용되고 있는지 구체적인 예시 좀 알려주세요 2. <b>코딩</b>을 배움으로써 행정에서 어떻게... 활용한 <b>코딩</b>은 기본적으로 프로그램을 개발하는데 쓰입니다. 전자기기가 날이갈수록 늘어나는만큼 <b>코딩</b> 자체도 우리... '}, {'title': '강남<b>코딩</b>학원 어디가좋나요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=400756801&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=710&search_sort=0&spq=0', 'description': '<b>코딩</b>을 배우기 위해 강남에 위치한 강남<b>코딩</b>학원을 알아보고 있어요. <b>코딩</b>을 초보자도 기초부터 가르쳐주는 강남<b>코딩</b>학원은 어디가 좋을지 강남역 부근에 있는 곳으로 알려주세요~~  강남<b>코딩</b>학원은 강남역 부근에 위치한... '}, {'title': '<b>코딩</b> 부트캠프 질문 있습니다', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=411577691&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=711&search_sort=0&spq=0', 'description': '<b>코딩</b>에 대한 지식이 없는 비전공자도 신청해서 ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:30 +0900', 'total': 413852, 'start': 801, 'display': 100, 'items': [{'title': '<b>코딩</b> 컴퓨터 또는 노트북 추천', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50202&docId=407928643&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=801&search_sort=0&spq=0', 'description': '... 비전공이지만 <b>코딩</b>에 관심이 생겨서 배우고자 하는... 선능으로는 <b>코딩</b>이 힘들것 같아 컴퓨터나 노트북 추천받으려고 합니다. <b>코딩</b> 공부 뭐 할지는 모릅니다ㅠ 아직... 할수있는 <b>코딩</b>이나 프로그래밍은 제외) 제품 을 추천받고자... '}, {'title': '<b>코딩</b>배우기', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=412654853&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=802&search_sort=0&spq=0', 'description': '17살이고 공고에 다니는데 아직 입학을 안해서 전자과는 무슨 수업을 받는지 모르지만 제가 갑자기 <b>코딩</b>에 관심이... 전자과에서도 <b>코딩</b>을 배우는데 IT랑 다른 언어를 배울 겁니다. IT에 관심이 있으시면 IT관련된 <b>코딩</b>을 배우시면... '}, {'title': '<b>코딩</b>, 프로그래밍 관련 자격증', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=411680271&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=803&search_sort=0&spq=0', 'description': '<b>코딩</b>, 프로그래밍 관련 자격증들을 나열해주시고 획득조건?에 관해서 같이 써주시면 감사하겠습니다. 예)... 자격증이나, <b>코딩</b>지도사 자격증이 질문자님께서 원하는 자격증에 해당하는 것 같네요 아래에서 해당... '}, {'title': '<b>코딩</b> 학원 비교', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=408273034&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=804&search_sort=0&spq=0', 'description': '현재 대학생이구 방학동안 <b>코딩</b>에 발좀 담궈보려는 학생입니당. 현재 sbs랑... 배우려는건 <b>코딩</b>쪽이고 자바나 c언어 생각하고있습니다  말씀하신대로 sbs는... <b>코딩</b>을 배우고싶다고 하셨으면 무엇보다 학생분께서 이 분야에 관해... '}, {'title': '<b>코딩</b> 공부', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=415817486&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=805&search_sort=0&spq=0', 'description': '컴공과 2학년인데 <b>코딩</b> 공부를 어케해야할지 진짜 모르겠어요 이게 저랑 맞는... <b>코딩</b> 공부를 어케햐아할까요.. 문법을 그냥 주구장창 외우ㅜ야 할까요?... 다녔듯이 <b>코딩</b>학원을 다니면서 강사님께 바로바로 피드백을 받으시는걸... '}, {'title': '<b>코딩</b>지도사', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=111&docId=412838882&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=806&search_sort=0&spq=0', 'description': '<b>코딩</b>지도사 1급 자격증 따면 바로 취업할 수 있나요?  안녕하세요 :D <b>코딩</b>지도사 취업에 대해 질문 주셨네요. 사실상 <b>코딩</b>지도사 자격증으로 취업을 하는건 거의 불가능... 몇 없는 <b>코딩</b>학원들도 전부 실무자 중심으로 스킬을 보고 채용을... '}, {'title': '<b>코딩</b>책 추천 좀 해주세요!', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=2&dirId=212&docId=412467227&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=807&search_sort=0&spq=0', 'description': '제가 <b>코딩</b>으로 간단한 게임 같은 거 만들고 싶은데 유튜브에 찾아보니 다들 파이썬이나 유니티같은 <b>코딩</b>을... 안녕하세요 사실 <b>코딩</b>은 글로 된 책으로는 이해하는게 한계가... 둘다 <b>코딩</b>이기는 한데 만들 수 있는 결과물이 완전 달라서... '}, {'title': '<b>코딩</b>을 한번 배워보고 싶어요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=403981603&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=808&search_sort=0&spq=0', 'description': '아는건 1도없고 <b>코딩</b>을 처음으로 배워보려 하는데 뭐부터 해야할까요? ( 책,프로그램 등...) <b>코딩</b>, IT공부와 관련하여 한번도 배워본 적이 없다면 완전히 기초부터 배우시는걸 추천드립니다. 관련 기초인강 링크 남겨드릴테니 한번... '}, {'title': '<b>코딩</b> 배우면 취업 마니 되나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=402087840&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=809&search_sort=0&spq=0', 'description': '<b>코딩</b> 배우면 취업 마니 되나요? <b>코딩</b>만 배워서 취업이 되는 건 아니지만 <b>코딩</b>이 포함되어있는 IT직군이 취업률이 높은 건 맞아요. IT직군 취업을 생각하고 계신가요? 어떤직업이 있는지, 어떤 공부를 해야 하는지 잘 모르겠다면 아래로... '}, {'title': '<b>코딩</b>배우기 학원이 좋나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=414884927&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=810&search_sort=0&spq=0', 'description': '... 관심있던 <b>코딩</b>을 배우고 싶어서요 <b>코딩</b>배우기가 독학으론 힘들고 학원이 괜찮을것 같은데 <b>코딩</b>학원 잘하는곳... 나가서 <b>코딩</b>배우라 해여 ㅋㅋㅋㅋㅋ 여기도 괜찮고 인강+책 조합도 괜찮아요. 나이가 좀 어리셔서 독학은 어렵겠지만요... '}, {'title': '<b>코딩</b> 캐드', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1020302&docId=412380547&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=811&search_sort=0&spq=0', 'description': '<b>코딩</b>이랑 캐드가 아예 다른 면일까요? 보통 학원들 보면 <b>코딩</b> 학원 따로 캐드 학원 따로일까여? 두 과목을 한... KG아이티뱅크에서는 <b>코딩</b>을 배우시고 KG인테리어뱅크에서는 CAD를 배우시면 됩니다! 다른 학원처럼 보이지만 같은... ' ...
# {'lastBuildDate': 'Sat, 07 May 2022 23:47:30 +0900', 'total': 413852, 'start': 901, 'display': 100, 'items': [{'title': '<b>코딩</b>지도사 자격증', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=395578257&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=901&search_sort=0&spq=0', 'description': '안녕하세요 <b>코딩</b>지도사 자격증을 취득하려고 합니다. 요즘 학교에서 방과후나 방학 특강으로 <b>코딩</b>을 많이 하더라고요. 궁금한점이 <b>코딩</b> 지도사 1급이라는 것을 알게... (교원자격증 소지) 아니면 보통하시는 분들은 <b>코딩</b> 외에... '}, {'title': '<b>코딩</b>테스트 질문', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=415018788&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=902&search_sort=0&spq=0', 'description': '<b>코딩</b>테스트 관련 인강이나 교육 추천해주세요. 참고로 비전공자이고 코테 관련해서는 거의 지식이 없는 상태입니다.... 프로그래밍 기초 배워보실 수 있고 웹<b>코딩</b>도 처음부터 차근차근 공부해보신다면 학원 링크 한번 남겨드립니다~'}, {'title': '죽전, 분당 쪽에서 <b>코딩</b>학원 추천해주세요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=405533948&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=903&search_sort=0&spq=0', 'description': '... 빼고 <b>코딩</b>에 집중할 수 있는 학원이었음 좋겠어요 광고 사절입니다 안녕하세요 죽전 분당 대학생 <b>코딩</b>수업... 누구나 <b>코딩</b>을 배울 수 있습니다. 교육청에 정식 등록을 하고 <b>코딩</b> 수업을 하고있으며 선생님과 일대일 수업이기때문에... '}, {'title': '서울<b>코딩</b>학원 어디가 좋나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110703&docId=403768998&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=904&search_sort=0&spq=0', 'description': '... 서울<b>코딩</b>학원을 알아보던 중 너무 많기도 해서 어디를 다녀야할지 잘 모르겠습니다. 서울<b>코딩</b>학원은 다... 서울<b>코딩</b>학원은 어디가 좋은지 질문 남깁니다. 안녕하세요! 서울<b>코딩</b>학원은 우리나라 학원가라고 불리오는 지역에 굉장히... '}, {'title': '<b>코딩</b>에대해서 알고 싶습니다.', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110212&docId=288997802&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=905&search_sort=0&spq=0', 'description': '... 요즘 <b>코딩</b>과목이 정규과목이 된다는 얘기가 있던데, <b>코딩</b>이 굉장히 낯설게 느껴집니다. <b>코딩</b>이 어떤 과목이고... <b>코딩</b>은 하나의 과목이 아니라 쉽게 생각하시면 컴퓨터와 대화하는 것을 배운다고 생각하시면 됩니다. <b>코딩</b>을 시작할... '}, {'title': '동아리 <b>코딩</b> 활동', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110414&docId=415240828&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=906&search_sort=0&spq=0', 'description': '동아리에서 <b>코딩</b> 활동을 하려고 하는데 무슨 활동을 하면 좋을까요  앱인벤터와 파이썬 추천드려요! 둘 다 실용적이고... 마지막으로, 이것들을 활동해서 뭔가 작품을 만들어놓으면 초중학교 대상 <b>코딩</b> 교육도 진행할 수 있어... '}, {'title': '<b>코딩</b> 국비지원교육', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110704&docId=410201088&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=907&search_sort=0&spq=0', 'description': '제가 <b>코딩</b>을 배우려고 하는데 국비지원교육으로 듣고싶습니다. 지금 충남 아산에 거주하는데 근처에는 별로... 지방쪽은 <b>코딩</b> 개발자 과정이 많이 있지는 않아서 서울권으로 올라오시는게 좋을 것 같습니다. 국비과정이나 개발자... '}, {'title': '대학생 <b>코딩</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=396588438&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=908&search_sort=0&spq=0', 'description': '요새 초등학생들에게 <b>코딩</b>이 의무교육이라는데... 방학을 의미있게 보내고 싶어서 <b>코딩</b>공부를 해볼까하는데... 도움되려 <b>코딩</b>을 공부하는 학생들이 늘어나는데 IT 전공... 쪽에서도 <b>코딩</b>을 고민하고 있는데 일부 대기업들은... '}, {'title': '<b>코딩</b> 공부 과정 질문', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=414466060&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=909&search_sort=0&spq=0', 'description': '이제 막 <b>코딩</b> 공부를 시작한 23세 남성입니다. 최대한 빠른 시간 내에 <b>코딩</b> 분야로 취업하고 싶습니다. 현재 파이썬... 우선 <b>코딩</b>에 기본 언어인 C언어부터 공부를 하시는 게... 아래에 <b>코딩</b>부터 다양한 정보들이 들어있습니다 이걸... '}, {'title': '어른 <b>코딩</b> 독학 조언 부탁드려요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=410693226&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=910&search_sort=0&spq=0', 'description': '<b>코딩</b>배워서 그쪽으로 취업하려는건 아닙니다. 물론, 제가 수준높은 <b>코딩</b> 능력을 소화해낼수있고, 시대적흐름이... 현시점에서 미래에 취업시장이 어떻게 될지 모르는상황에서 <b>코딩</b>을 어떻게 독학을 해야할가요...? 질문2. <b>코딩</b>을 어느정도... '}, {'title': '경남, 부산 <b>코딩</b> 고등학교', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110308&docId=406454687&qb=7L2U65Sp&enc=utf8&section=kin.qna&rank=911&search_sort=0&spq=0', 'description': '... 해커라서 <b>코딩</b> 고등학교를 가고 싶은데 어디로 가야할지 모르겠습니다.... <b>코딩</b>관련고등학교 중에 부산에 소프트웨어마이스터고가 있습니다.... 그러기 위해서는 <b>코딩</b>을 ...
