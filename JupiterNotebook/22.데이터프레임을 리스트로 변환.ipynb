# %% [markdown]
# ## 데이터프레임->시리즈->리스트로 변환 tolist()

# %%
import pandas as pd

df= pd.read_csv('경기_행복주택현황.csv', encoding='cp949',index_col = 1)
df
# Out:
#                                          사업지구명  공급세대수        준공일자     유형  \
# 위치정보
# 경기도 화성동탄 2 신도시 내 A76-1BL(산척동 750)      동탄 호수공원    995  2020-10-16   신혼부부
# 경기도 화성시 진안동 524-3                       화성 진안1     16  2017-12-21     청년
# 경기도 화성시 진안동 882-1                       화성 진안2     15  2018-02-28     청년
# 경기도 평택시 포승황해경제자유구역 내 평택BIX A-2          평택 BIX    330  2021-04-30  산업단지형
# 경기도 평택시 고덕국제화계획지구 A-62블럭               고덕 서정리역    800         NaN   신혼부부
# 경기도 연천군 통현리 812번지(연천BIX 주거1)            연천 BIX    100         NaN  산업단지형
# 경기도 남양주시 다산동 6027                        다산역A2    970  2019-09-02   신혼부부
# 경기도 남양주시 다산신도시 지금A5 BL                 다산지금 A5   2078         NaN   신혼부부
# 경기도 가평군 가평읍 읍내리 608-5                   가평청사복합     42  2019-06-17     청년
# 경기도 광주역세권 도시개발사업지구 A2BL(역동 169-11일원)    경기 광주역    500         NaN   신혼부부
# 경기도 양평군 양평읍 공흥리 441-22                   양평 공흥     40  2019-01-28     청년
# 경기도 양평군 창대리 701, 700-3                  양평 남한강     49         NaN   신혼부부
# ...

# %%
import pandas as pd

df= pd.read_csv('경기_행복주택현황.csv', encoding='cp949')
df2 = df['유형']
df2
# Out:
# 0      신혼부부
# 1        청년
# 2        청년
# 3     산업단지형
# 4      신혼부부
# 5     산업단지형
# 6      신혼부부
# 7      신혼부부
# 8        청년
# 9      신혼부부
# 10       청년
# 11     신혼부부
# 12       청년
# 13     신혼부부
# 14       청년
# 15       청년
# 16       청년
# 17    산업단지형
# 18       청년
# 19    산업단지형
# 20       청년
# 21     신혼부부
# 22       청년
# 23       청년
# 24      실버형
# 25     신혼부부
# 26    산업단지형
# 27     신혼부부
# 28    산업단지형
# 29       청년
# 30       청년
# Name: 유형, dtype: object

# %%
import pandas as pd

df= pd.read_csv('경기_행복주택현황.csv', encoding='cp949')
df2 = df['유형']
type(df2)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

df= pd.read_csv('경기_행복주택현황.csv', encoding='cp949')
df2 = df['유형'].tolist()
type(df2)
# Out:
# list

# %%
import pandas as pd
import numpy as np
df= pd.read_csv('경기_행복주택현황.csv', encoding='cp949',index_col = 1)

dic_list = df['유형'].tolist()
print(dic_list)
# Out:
# ['신혼부부', '청년', '청년', '산업단지형', '신혼부부', '산업단지형', '신혼부부', '신혼부부', '청년', '신혼부부', '청년', '신혼부부', '청년', '신혼부부', '청년', '청년', '청년', '산업단지형', '청년', '산업단지형', '청년', '신혼부부', '청년', '청년', '실버형', '신혼부부', '산업단지형', '신혼부부', '산업단지형', '청년', '청년']
